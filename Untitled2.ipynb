# %%
import pandas
csvFile = pandas.read_csv('imdb-movies-dataset.csv')
print(csvFile)
# Out:
#                                                  Poster  \
# 0     https://m.media-amazon.com/images/M/MV5BYWRkZj...
# 1     https://m.media-amazon.com/images/M/MV5BZGI4NT...
# 2     https://m.media-amazon.com/images/M/MV5BZjIyOT...
# 3     https://m.media-amazon.com/images/M/MV5BMjA5Zj...
# 4     https://m.media-amazon.com/images/M/MV5BNTk1MT...
# ...                                                 ...
# 9995  https://m.media-amazon.com/images/M/MV5BMzg5MW...
# 9996  https://m.media-amazon.com/images/M/MV5BYzA0ZG...
# 9997  https://m.media-amazon.com/images/M/MV5BM2U1Mj...
# 9998  https://m.media-amazon.com/images/M/MV5BMTAwOD...
# 9999  https://m.media-amazon.com/images/M/MV5BMmE4ZD...
#
#                                             Title    Year Certificate  \
# 0                                 The Idea of You  2023.0           R
# 1               Kingdom of the Planet of the Apes  2023.0       PG-13
# 2                                       Unfrosted  2023.0       PG-13
# ...

# %%
csvFile.head()
# Out:
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BYWRkZj...
# 1  https://m.media-amazon.com/images/M/MV5BZGI4NT...
# 2  https://m.media-amazon.com/images/M/MV5BZjIyOT...
# 3  https://m.media-amazon.com/images/M/MV5BMjA5Zj...
# 4  https://m.media-amazon.com/images/M/MV5BNTk1MT...
#
#                                Title    Year Certificate  Duration (min)  \
# 0                    The Idea of You  2023.0           R           115.0
# 1  Kingdom of the Planet of the Apes  2023.0       PG-13           145.0
# 2                          Unfrosted  2023.0       PG-13            97.0
# 3                       The Fall Guy  2023.0       PG-13           126.0
# 4                        Challengers  2023.0           R           131.0
#
#                         Genre  Rating  Metascore           Director  \
# 0      Comedy, Drama, Romance     6.4       67.0  Michael Showalter
# ...

# %%
csvFile.dropna()
# Out:
#                                                  Poster  \
# 0     https://m.media-amazon.com/images/M/MV5BYWRkZj...
# 1     https://m.media-amazon.com/images/M/MV5BZGI4NT...
# 2     https://m.media-amazon.com/images/M/MV5BZjIyOT...
# 3     https://m.media-amazon.com/images/M/MV5BMjA5Zj...
# 4     https://m.media-amazon.com/images/M/MV5BNTk1MT...
# ...                                                 ...
# 9990  https://m.media-amazon.com/images/M/MV5BNjFjYm...
# 9993  https://m.media-amazon.com/images/M/MV5BMzRkNj...
# 9994  https://m.media-amazon.com/images/M/MV5BNmRhZW...
# 9995  https://m.media-amazon.com/images/M/MV5BMzg5MW...
# 9998  https://m.media-amazon.com/images/M/MV5BMTAwOD...
#
#                                   Title    Year Certificate  Duration (min)  \
# 0                       The Idea of You  2023.0           R           115.0
# 1     Kingdom of the Planet of the Apes  2023.0       PG-13           145.0
# ...

# %%
before = type(csvFile.Year[0])

# %%
csvFile.Year = csvFile.Year.astype('int64')

# %%
csvFile.dropna(inplace=True)

# %%
after = type(csvFile.Year[0])

# %%
before
# Out:
# numpy.float64

# %%
after
# Out:
# numpy.int64

# %%
csvFile
# Out:
#                                                  Poster  \
# 0     https://m.media-amazon.com/images/M/MV5BYWRkZj...
# 1     https://m.media-amazon.com/images/M/MV5BZGI4NT...
# 2     https://m.media-amazon.com/images/M/MV5BZjIyOT...
# 3     https://m.media-amazon.com/images/M/MV5BMjA5Zj...
# 4     https://m.media-amazon.com/images/M/MV5BNTk1MT...
# ...                                                 ...
# 9990  https://m.media-amazon.com/images/M/MV5BNjFjYm...
# 9993  https://m.media-amazon.com/images/M/MV5BMzRkNj...
# 9994  https://m.media-amazon.com/images/M/MV5BNmRhZW...
# 9995  https://m.media-amazon.com/images/M/MV5BMzg5MW...
# 9998  https://m.media-amazon.com/images/M/MV5BMTAwOD...
#
#                                   Title  Year Certificate  Duration (min)  \
# 0                       The Idea of You  2023           R           115.0
# 1     Kingdom of the Planet of the Apes  2023       PG-13           145.0
# ...

# %%
csvFile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6404 entries, 0 to 9998
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Poster          6404 non-null   object
#  1   Title           6404 non-null   object
#  2   Year            6404 non-null   int64
#  3   Certificate     6404 non-null   object
#  4   Duration (min)  6404 non-null   float64
#  5   Genre           6404 non-null   object
#  6   Rating          6404 non-null   float64
#  7   Metascore       6404 non-null   int64
#  8   Director        6404 non-null   object
#  9   Cast            6404 non-null   object
#  10  Votes           6404 non-null   object
#  11  Description     6404 non-null   object
#  12  Review Count    6404 non-null   object
#  13  Review Title    6404 non-null   object
#  14  Review          6404 non-null   object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 1.0+ MB

# %%
csvFile.describe()
# Out:
#               Year  Duration (min)       Rating    Metascore
# count  6404.000000     6404.000000  6404.000000  6404.000000
# mean   2006.289975      110.068395     6.548782  2006.289975
# std      18.284315       19.477238     0.938561    18.284315
# min    1929.000000       55.000000     1.900000  1929.000000
# 25%    1997.000000       97.000000     6.000000  1997.000000
# 50%    2012.000000      107.000000     6.600000  2012.000000
# 75%    2021.000000      119.000000     7.200000  2021.000000
# max    2025.000000      321.000000     9.300000  2025.000000
